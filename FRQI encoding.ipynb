# %%
# Importing standard Qiskit libraries
import qiskit as qk
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit import transpile, assemble
# from qiskit.tools.jupyter import *
from qiskit.visualization import plot_histogram
from math import pi

# %%
theta = 0 # all pixels black
qc = QuantumCircuit(3)

qc.h(0)
qc.h(1)

qc.barrier()
#Pixel 1

qc.cry(theta,0,2)
qc.cx(0,1)
qc.cry(-theta,1,2)
qc.cx(0,1)
qc.cry(theta,1,2)

qc.barrier()
#Pixel 2

qc.x(1)
qc.cry(theta,0,2)
qc.cx(0,1)
qc.cry(-theta,1,2)
qc.cx(0,1)
qc.cry(theta,1,2)

qc.barrier()

qc.x(1)
qc.x(0)
qc.cry(theta,0,2)
qc.cx(0,1)
qc.cry(-theta,1,2)
qc.cx(0,1)
qc.cry(theta,1,2)


qc.barrier()

qc.x(1)

qc.cry(theta,0,2)
qc.cx(0,1)
qc.cry(-theta,1,2)
qc.cx(0,1)
qc.cry(theta,1,2)

qc.measure_all()

qc.draw()
# Out:
#         ┌───┐ ░                                       ░                    »
#    q_0: ┤ H ├─░─────■──────■─────────────■────────────░──────────■──────■──»
#         ├───┤ ░     │    ┌─┴─┐         ┌─┴─┐          ░ ┌───┐    │    ┌─┴─┐»
#    q_1: ┤ H ├─░─────┼────┤ X ├────■────┤ X ├────■─────░─┤ X ├────┼────┤ X ├»
#         └───┘ ░ ┌───┴───┐└───┘┌───┴───┐└───┘┌───┴───┐ ░ └───┘┌───┴───┐└───┘»
#    q_2: ──────░─┤ Ry(0) ├─────┤ Ry(0) ├─────┤ Ry(0) ├─░──────┤ Ry(0) ├─────»
#               ░ └───────┘     └───────┘     └───────┘ ░      └───────┘     »
# meas: 3/═══════════════════════════════════════════════════════════════════»
#                                                                            »
# «                                ░ ┌───┐                                     »
# «   q_0: ───────────■────────────░─┤ X ├────■──────■─────────────■───────────»
# «                 ┌─┴─┐          ░ ├───┤    │    ┌─┴─┐         ┌─┴─┐         »
# ...

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

# Define your quantum circuit (qc) here

# Transpile the circuit for the simulator
aer_sim = Aer.get_backend('aer_simulator')
t_qc = transpile(qc, aer_sim)

# Execute the circuit on the simulator (replaced assemble)
job = aer_sim.run(t_qc, shots=4096)

# Get the counts from the job result
result = job.result()
counts = result.get_counts(qc)

# Print the counts
print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# {'001': 1023, '000': 1030, '011': 1012, '010': 1031}

# %%
theta = pi/2  # all pixels white
qc1 = QuantumCircuit(3)

qc1.h(0)
qc1.h(1)

qc1.barrier()
#Pixel 1

qc1.cry(theta,0,2)
qc1.cx(0,1)
qc1.cry(-theta,1,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)

qc1.barrier()
#Pixel 2

qc1.x(1)

qc1.cry(theta,0,2)
qc1.cx(0,1)
qc1.cry(-theta,1,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)

qc1.barrier()

qc1.x(1)
qc1.x(0)
qc1.cry(theta,0,2)
qc1.cx(0,1)
qc1.cry(-theta,1,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)


qc1.barrier()

qc1.x(1)

qc1.cry(theta,0,2)
qc1.cx(0,1)
qc1.cry(-theta,1,2)
qc1.cx(0,1)
qc1.cry(theta,1,2)

qc1.measure_all()

qc1.draw()
# Out:
#         ┌───┐ ░                                              ░                 »
#    q_0: ┤ H ├─░──────■───────■────────────────■──────────────░───────────■─────»
#         ├───┤ ░      │     ┌─┴─┐            ┌─┴─┐            ░ ┌───┐     │     »
#    q_1: ┤ H ├─░──────┼─────┤ X ├─────■──────┤ X ├─────■──────░─┤ X ├─────┼─────»
#         └───┘ ░ ┌────┴────┐└───┘┌────┴─────┐└───┘┌────┴────┐ ░ └───┘┌────┴────┐»
#    q_2: ──────░─┤ Ry(π/2) ├─────┤ Ry(-π/2) ├─────┤ Ry(π/2) ├─░──────┤ Ry(π/2) ├»
#               ░ └─────────┘     └──────────┘     └─────────┘ ░      └─────────┘»
# meas: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                          ░ ┌───┐                            »
# «   q_0: ──■────────────────■──────────────░─┤ X ├─────■───────■──────────────»
# «        ┌─┴─┐            ┌─┴─┐            ░ ├───┤     │     ┌─┴─┐            »
# ...

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

# Define your quantum circuit (qc) here

# Transpile the circuit for the simulator
aer_sim = Aer.get_backend('aer_simulator')
t_qc = transpile(qc, aer_sim)

# Execute the circuit on the simulator (replaced assemble)
job = aer_sim.run(t_qc, shots=4096)

# Get the counts from the job result
result = job.result()
counts = result.get_counts(qc)

# Print the counts
print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# {'011': 1000, '000': 1067, '001': 1037, '010': 992}

# %%
theta = pi/4  # all pixels white
qc2 = qk.QuantumCircuit(3)

qc2.h(0)
qc2.h(1)

qc2.barrier()
#Pixel 1

qc2.cry(theta,0,2)
qc2.cx(0,1)
qc2.cry(-theta,1,2)
qc2.cx(0,1)
qc2.cry(theta,1,2)

qc2.barrier()
#Pixel 2

qc2.x(1)

qc2.cry(theta,0,2)
qc2.cx(0,1)
qc2.cry(-theta,1,2)
qc2.cx(0,1)
qc2.cry(theta,1,2)

qc2.barrier()

qc2.x(1)
qc2.x(0)
qc2.cry(theta,0,2)
qc2.cx(0,1)
qc2.cry(-theta,1,2)
qc2.cx(0,1)
qc2.cry(theta,1,2)


qc2.barrier()

qc2.x(1)

qc2.cry(theta,0,2)
qc2.cx(0,1)
qc2.cry(-theta,1,2)
qc2.cx(0,1)
qc2.cry(theta,1,2)

qc2.measure_all()

qc2.draw()
# Out:
#         ┌───┐ ░                                              ░                 »
#    q_0: ┤ H ├─░──────■───────■────────────────■──────────────░───────────■─────»
#         ├───┤ ░      │     ┌─┴─┐            ┌─┴─┐            ░ ┌───┐     │     »
#    q_1: ┤ H ├─░──────┼─────┤ X ├─────■──────┤ X ├─────■──────░─┤ X ├─────┼─────»
#         └───┘ ░ ┌────┴────┐└───┘┌────┴─────┐└───┘┌────┴────┐ ░ └───┘┌────┴────┐»
#    q_2: ──────░─┤ Ry(π/4) ├─────┤ Ry(-π/4) ├─────┤ Ry(π/4) ├─░──────┤ Ry(π/4) ├»
#               ░ └─────────┘     └──────────┘     └─────────┘ ░      └─────────┘»
# meas: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                          ░ ┌───┐                            »
# «   q_0: ──■────────────────■──────────────░─┤ X ├─────■───────■──────────────»
# «        ┌─┴─┐            ┌─┴─┐            ░ ├───┤     │     ┌─┴─┐            »
# ...

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

# Define your quantum circuit (qc2) here

# Transpile the circuit for the simulator
aer_sim = Aer.get_backend('aer_simulator')
t_qc2 = transpile(qc2, aer_sim)

# Execute the circuit on the simulator (replaced assemble)
job = aer_sim.run(t_qc2, shots=4096)

# Get the counts from the job result
result = job.result()
counts = result.get_counts(qc2)

# Print the counts
print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# {'100': 512, '110': 489, '101': 526, '111': 485, '010': 510, '000': 515, '011': 530, '001': 529}

# %%
print("Depth: ", qc1.depth())
print("Operations: ", qc1.count_ops())
# Out:
# Depth:  23
# Operations:  OrderedDict([('cry', 12), ('cx', 8), ('barrier', 5), ('x', 4), ('measure', 3), ('h', 2)])

# %%
from qiskit.compiler import transpile
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import BasisTranslator
from qiskit.circuit.equivalence_library import SessionEquivalenceLibrary

# Define the target basis gates (same as 'u3' and 'cx')
target_basis = ['u3', 'cx']

# Use BasisTranslator instead of Unroller
pass_ = BasisTranslator(SessionEquivalenceLibrary, target_basis)
pm = PassManager(pass_)

# Transpile the circuit to the target basis gates
new_circ = pm.run(qc1)

# Draw the new circuit
new_circ.draw()
# Out:
#         ┌─────────────┐ ░                                          »
#    q_0: ┤ U3(π/2,0,π) ├─░──────────────────■────────────────────■──»
#         ├─────────────┤ ░                  │                    │  »
#    q_1: ┤ U3(π/2,0,π) ├─░──────────────────┼────────────────────┼──»
#         └─────────────┘ ░ ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐»
#    q_2: ────────────────░─┤ U3(π/4,0,0) ├┤ X ├┤ U3(-π/4,0,0) ├┤ X ├»
#                         ░ └─────────────┘└───┘└──────────────┘└───┘»
# meas: 3/═══════════════════════════════════════════════════════════»
#                                                                    »
# «                                                                     »
# «   q_0: ───────■────────────────────────────────────────■────────────»
# «             ┌─┴─┐                                    ┌─┴─┐          »
# «   q_1: ─────┤ X ├────────■───────────────────■───────┤ X ├───────■──»
# ...

# %%
print("Depth : ", new_circ.depth())
print("Operations: ", new_circ.count_ops())
# Out:
# Depth :  50
# Operations:  OrderedDict([('cx', 32), ('u3', 30), ('barrier', 5), ('measure', 3)])
